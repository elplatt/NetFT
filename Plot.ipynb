# %%
# %pylab inline
import os
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_rt = "archive/router_targeted/2017-10-07 13:50:31 bfb4f6a/targeted_router.csv"
data_rr = [
    "archive/router_random/2017-10-08 11:47:42 4717097/targeted_router.csv",
    "archive/router_random 1/2017-10-08 20:34:54 be0a099 /targeted_router.csv",
    "archive/router_random 2/2017-10-08 20:34:47 be0a099 /targeted_router.csv",
    "archive/router_random 3/2017-10-08 20:34:47 be0a099 /targeted_router.csv",
    "archive/router_random 4/2017-10-08 20:34:48 be0a099 /targeted_router.csv",
    "archive/router_random 5/2017-10-08 20:34:48 be0a099 /targeted_router.csv",
    "archive/router_random 6/2017-10-08 20:34:48 be0a099 /targeted_router.csv",
    "archive/router_random 7/2017-10-08 20:34:48 be0a099 /targeted_router.csv",
    "archive/router_random 8/2017-10-08 20:34:48 be0a099 /targeted_router.csv",
    "archive/router_random 9/2017-10-08 20:34:49 be0a099 /targeted_router.csv",
]
data_rbt00 = [
    "archive/router_targeted_00/2017-10-24 11:37:52 fbb47d5 1/stats.csv",
    "archive/router_targeted_00/2017-10-24 11:37:52 fbb47d5 10/stats.csv",
    "archive/router_targeted_00/2017-10-24 11:37:52 fbb47d5 3/stats.csv",
    "archive/router_targeted_00/2017-10-24 11:37:52 fbb47d5 7/stats.csv",
    "archive/router_targeted_00/2017-10-24 11:38:02 fbb47d5 2/stats.csv",
    "archive/router_targeted_00/2017-10-24 11:38:02 fbb47d5 4/stats.csv",
    "archive/router_targeted_00/2017-10-24 11:38:02 fbb47d5 5/stats.csv",
    "archive/router_targeted_00/2017-10-24 11:38:02 fbb47d5 6/stats.csv",
    "archive/router_targeted_00/2017-10-24 11:38:02 fbb47d5 8/stats.csv",
    "archive/router_targeted_00/2017-10-24 11:38:02 fbb47d5 9/stats.csv"
]
data_rbt10 = [
    "archive/router_targeted_10/2017-10-23 11:48:14 fbb47d5 1/stats.csv",
    "archive/router_targeted_10/2017-10-23 11:48:14 fbb47d5 3/stats.csv",
    "archive/router_targeted_10/2017-10-23 11:48:14 fbb47d5 4/stats.csv",
    "archive/router_targeted_10/2017-10-23 11:48:14 fbb47d5 5/stats.csv",
    "archive/router_targeted_10/2017-10-23 11:48:18 fbb47d5 10/stats.csv",
    "archive/router_targeted_10/2017-10-23 11:48:18 fbb47d5 2/stats.csv",
    "archive/router_targeted_10/2017-10-23 11:48:18 fbb47d5 6/stats.csv",
    "archive/router_targeted_10/2017-10-23 11:48:18 fbb47d5 7/stats.csv",
    "archive/router_targeted_10/2017-10-23 11:48:18 fbb47d5 8/stats.csv",
    "archive/router_targeted_10/2017-10-23 11:48:18 fbb47d5 9/stats.csv"
]
data_rbt50 = [
    "archive/router_targeted_50/2017-10-24 23:12:28 7c1aefb 1/stats.csv",
    "archive/router_targeted_50/2017-10-24 23:12:28 7c1aefb 10/stats.csv",
    "archive/router_targeted_50/2017-10-24 23:12:28 7c1aefb 2/stats.csv",
    "archive/router_targeted_50/2017-10-24 23:12:28 7c1aefb 3/stats.csv",
    "archive/router_targeted_50/2017-10-24 23:12:28 7c1aefb 4/stats.csv",
    "archive/router_targeted_50/2017-10-24 23:12:28 7c1aefb 5/stats.csv",
    "archive/router_targeted_50/2017-10-24 23:12:28 7c1aefb 7/stats.csv",
    "archive/router_targeted_50/2017-10-24 23:12:28 7c1aefb 8/stats.csv",
    "archive/router_targeted_50/2017-10-24 23:12:28 7c1aefb 9/stats.csv",
    "archive/router_targeted_50/2017-10-24 23:12:40 7c1aefb 6/stats.csv"
]
data_rbt90 = [
    "archive/router_targeted_90/2017-10-24 11:38:56 fbb47d5 1/stats.csv",
    "archive/router_targeted_90/2017-10-24 11:38:57 fbb47d5 2/stats.csv",
    "archive/router_targeted_90/2017-10-24 11:38:57 fbb47d5 4/stats.csv",
    "archive/router_targeted_90/2017-10-24 11:39:01 fbb47d5 5/stats.csv",
    "archive/router_targeted_90/2017-10-24 11:39:01 fbb47d5 6/stats.csv",
    "archive/router_targeted_90/2017-10-24 11:39:03 fbb47d5 10/stats.csv",
    "archive/router_targeted_90/2017-10-24 11:39:03 fbb47d5 3/stats.csv",
    "archive/router_targeted_90/2017-10-24 11:39:03 fbb47d5 7/stats.csv",
    "archive/router_targeted_90/2017-10-24 11:39:03 fbb47d5 8/stats.csv",
    "archive/router_targeted_90/2017-10-24 11:39:03 fbb47d5 9/stats.csv",
]
data_rbr90 = [
    "archive/router_random/2017-10-12 20:59:29 d101dee 1/stats.csv",
    "archive/router_random/2017-10-12 20:59:31 d101dee 2/stats.csv",
    "archive/router_random/2017-10-12 20:59:29 d101dee 3/stats.csv",
    "archive/router_random/2017-10-12 20:59:38 d101dee 4/stats.csv",
    "archive/router_random/2017-10-12 20:59:29 d101dee 5/stats.csv",
    "archive/router_random/2017-10-12 20:59:38 d101dee 6/stats.csv",
    "archive/router_random/2017-10-12 20:59:31 d101dee 7/stats.csv",
    "archive/router_random/2017-10-12 20:59:29 d101dee 8/stats.csv",
    "archive/router_random/2017-10-12 20:59:29 d101dee 9/stats.csv",
    "archive/router_random/2017-10-12 20:59:29 d101dee 10/stats.csv"
]
data_tb = [
    "archive/butterfly_targeted/2017-10-24 11:50:53 7c1aefb 3/stats.csv",
    "archive/butterfly_targeted/2017-10-24 11:50:53 7c1aefb 4/stats.csv",
    "archive/butterfly_targeted/2017-10-24 11:50:53 7c1aefb 5/stats.csv",
    "archive/butterfly_targeted/2017-10-24 11:50:53 7c1aefb 6/stats.csv",
    "archive/butterfly_targeted/2017-10-24 11:50:54 7c1aefb 2/stats.csv",
    "archive/butterfly_targeted/2017-10-24 11:50:55 7c1aefb 1/stats.csv",
    "archive/butterfly_targeted/2017-10-24 11:50:55 7c1aefb 10/stats.csv",
    "archive/butterfly_targeted/2017-10-24 11:50:55 7c1aefb 7/stats.csv",
    "archive/butterfly_targeted/2017-10-24 11:50:55 7c1aefb 8/stats.csv",
    "archive/butterfly_targeted/2017-10-24 11:50:55 7c1aefb 9/stats.csv"
]

# %%
df_router_targ = pd.read_csv(data_rt)
df_router_rand = pd.concat([pd.read_csv(x) for x in data_rr])
df_rw_targ00 = pd.concat([pd.read_csv(x) for x in data_rbt00])
df_rw_targ10 = pd.concat([pd.read_csv(x) for x in data_rbt10])
df_rw_targ50 = pd.concat([pd.read_csv(x) for x in data_rbt50])
df_rw_targ90 = pd.concat([pd.read_csv(x) for x in data_rbt90])
df_tb = pd.concat([pd.read_csv(x) for x in data_tb])
#df_rw_rand10 = pd.concat([pd.read_csv(x) for x in data_rbr10])
#df_rw_rand90 = pd.concat([pd.read_csv(x) for x in data_rbr90])

# %%
df_router_targ["fraction"] = df_router_targ["removed"] / df_router_targ["node_count"]
df_router_rand["fraction"] = df_router_rand["removed"] / df_router_rand["node_count"]
df_rw_targ00["fraction"] = df_rw_targ10["removed"] / df_rw_targ00["node_count"]
df_rw_targ10["fraction"] = df_rw_targ10["removed"] / df_rw_targ10["node_count"]
df_rw_targ50["fraction"] = df_rw_targ50["removed"] / df_rw_targ50["node_count"]
df_rw_targ90["fraction"] = df_rw_targ90["removed"] / df_rw_targ90["node_count"]
df_tb["fraction"] = df_tb["removed"] / df_tb["node_count"]
#df_rw_rand90["fraction"] = df_rw_rand90["removed"] / df_rw_rand90["node_count"]
df_router_targ = df_router_targ[df_router_targ["removed"] < 500]
df_router_rand = df_router_rand[df_router_rand["removed"] < 500]
df_rw_targ00 = df_rw_targ00[df_rw_targ00["removed"] < 64]
df_rw_targ10 = df_rw_targ10[df_rw_targ10["removed"] < 148]
df_rw_targ50 = df_rw_targ50[df_rw_targ50["removed"] < 469]
df_rw_targ90 = df_rw_targ90[df_rw_targ90["removed"] < 500]
df_tb = df_tb[df_tb["removed"] < 500]
#df_rw_rand90 = df_rw_rand90[df_rw_rand90["removed"] < 500]

# %%
figure(figsize=(3,2.33))
#plt.subplot(1,2,1)
lw = 1
plt.plot(df_router_rand.groupby(["fraction"])["diameter"].mean(), 'k-', label="random - 0% rewired", linewidth=lw)
plt.plot(df_rw_targ00.groupby(["fraction"])["diameter"].mean(), 'r-', label="targeted - 0% rewired", linewidth=lw)
plt.plot(df_rw_targ10.groupby(["fraction"])["diameter"].mean(), 'g-.', label="targeted - 10% rewired", linewidth=lw)
plt.plot(df_rw_targ50.groupby(["fraction"])["diameter"].mean(), 'c--', label="targeted - 50% rewired", linewidth=lw)
plt.plot(df_rw_targ90.groupby(["fraction"])["diameter"].mean(), 'b:', label="targeted - 90% rewired", linewidth=lw)
plt.legend(fontsize=7)
plt.tick_params(axis='both', which='major', labelsize=11)
xlabel("Fraction Failed", fontsize=10)
ylabel("Diameter", fontsize=10)
plt.ylim([0, 140]); plt.yticks([0, 20, 40, 60, 80, 100, 120, 140])
plt.xlim([0, 0.08]); plt.xticks([0.0, 0.02, 0.04, 0.06, 0.08])
plt.grid()
plt.tight_layout()
plt.savefig("fig-diameter.png")
plt.savefig("fig-diameter.pdf")
plt.savefig("fig-diameter.eps")

# %%
figure(figsize=(10,2.5))
lw=1
plt.subplot(1,4,1)
plt.loglog(df_rw_targ00.groupby(["fraction"])["node_conn0_mean"].mean(), 'k-', label="0%", linewidth=lw)
plt.loglog(df_rw_targ10.groupby(["fraction"])["node_conn0_mean"].mean(), 'r:', label="10%", linewidth=lw)
plt.loglog(df_rw_targ50.groupby(["fraction"])["node_conn0_mean"].mean(), 'g-.', label="50%", linewidth=lw)
plt.loglog(df_rw_targ90.groupby(["fraction"])["node_conn0_mean"].mean(), 'b--', label="90%", linewidth=lw)
plt.grid()
plt.xlim([0.0001, 0.1]); plt.ylim([0.1, 10000])
plt.title("h=0", fontsize=10)
plt.xlabel("Fraction failed", fontsize=10); plt.ylabel("Mean min-cut", fontsize=10);
plt.legend(fontsize=7)
plt.subplot(1,4,2)
plt.loglog(df_rw_targ00.groupby(["fraction"])["node_conn1_mean"].mean(), 'k-', label="0%", linewidth=lw)
plt.loglog(df_rw_targ10.groupby(["fraction"])["node_conn1_mean"].mean(), 'r:', label="10%", linewidth=lw)
plt.loglog(df_rw_targ50.groupby(["fraction"])["node_conn1_mean"].mean(), 'g-.', label="50%", linewidth=lw)
plt.loglog(df_rw_targ90.groupby(["fraction"])["node_conn1_mean"].mean(), 'b--', label="90%", linewidth=lw)
plt.grid()
plt.xlim([0.0001, 0.1]); plt.ylim([0.1, 10000])
plt.title("h=1", fontsize=10)
plt.xlabel("Fraction failed", fontsize=10); plt.ylabel("Mean min-cut", fontsize=10);
plt.legend(fontsize=7)
plt.subplot(1,4,3)
plt.loglog(df_rw_targ00.groupby(["fraction"])["node_conn2_mean"].mean(), 'k-', label="0%", linewidth=lw)
plt.loglog(df_rw_targ10.groupby(["fraction"])["node_conn2_mean"].mean(), 'r:', label="10%", linewidth=lw)
plt.loglog(df_rw_targ50.groupby(["fraction"])["node_conn2_mean"].mean(), 'g-.', label="50%", linewidth=lw)
plt.loglog(df_rw_targ90.groupby(["fraction"])["node_conn2_mean"].mean(), 'b--', label="90%", linewidth=lw)
plt.grid()
plt.title("h=2", fontsize=10)
plt.xlabel("Fraction failed", fontsize=10); plt.ylabel("Mean min-cut", fontsize=10);
plt.legend(fontsize=7)
plt.xlim([0.0001, 0.1]); plt.ylim([0.1, 10000])
plt.subplot(1,4,4)
plt.loglog(df_rw_targ00.groupby(["fraction"])["node_conn3_mean"].mean(), 'k-', label="0%", linewidth=lw)
plt.loglog(df_rw_targ10.groupby(["fraction"])["node_conn3_mean"].mean(), 'r:', label="10%", linewidth=lw)
plt.loglog(df_rw_targ50.groupby(["fraction"])["node_conn3_mean"].mean(), 'g-.', label="50%", linewidth=lw)
plt.loglog(df_rw_targ90.groupby(["fraction"])["node_conn3_mean"].mean(), 'b--', label="90%", linewidth=lw)
plt.grid()
plt.xlim([0.0001, 0.1]); plt.ylim([0.1, 10000])
plt.title("h=3", fontsize=10)
plt.xlabel("Fraction failed", fontsize=10); plt.ylabel("Mean min-cut", fontsize=10);
plt.legend(fontsize=7)
plt.tight_layout()
plt.savefig(filename="fig-mincut.png")
plt.savefig(filename="fig-mincut.pdf")
plt.savefig(filename="fig-mincut.eps")

# %%
figure(figsize=(8,3))
lw=1
plt.subplot(1,2,1)
plt.loglog(df_tb.groupby(["fraction"])["node_conn0_mean"].mean(), 'k-', label="0%", linewidth=lw)
plt.loglog(df_tb.groupby(["fraction"])["node_conn1_mean"].mean(), 'k-', label="0%", linewidth=lw)
plt.loglog(df_tb.groupby(["fraction"])["node_conn2_mean"].mean(), 'k-', label="0%", linewidth=lw)
plt.loglog(df_tb.groupby(["fraction"])["node_conn3_mean"].mean(), 'k-', label="0%", linewidth=lw)
plt.subplot(1,2,2)
plt.plot(df_tb.groupby(["fraction"])["size_mean"].mean(), 'k-', label="0%", linewidth=lw)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-ca845fe211d7> in <module>()
#       7 plt.loglog(df_tb.groupby(["fraction"])["node_conn3_mean"].mean(), 'k-', label="0%", linewidth=lw)
#       8 plt.subplot(1,2,2)
# ----> 9 plt.plot(df_tb.groupby(["fraction"])["size_mean"].mean(), 'k-', label="0%", linewidth=lw)
#
# /home/elplatt/NetFT/venv/local/lib/python2.7/site-packages/pandas/core/base.pyc in __getitem__(self, key)
#     345         else:
#     346             if key not in self.obj:
# --> 347                 raise KeyError("Column not found: %s" % key)
#     348             return self._gotitem(key, ndim=1)
#     349
#
# KeyError: 'Column not found: size_mean'

# %%
max(df_tb["removed"])
# Out:
# 26
